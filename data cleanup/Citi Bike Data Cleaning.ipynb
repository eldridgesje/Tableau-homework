# %%
import pandas as pd

# %%
NY202001df = pd.read_csv (r'..\data\202001-citibike-tripdata.csv')
NY202002df = pd.read_csv (r'..\data\202002-citibike-tripdata.csv')
NY202003df = pd.read_csv (r'..\data\202003-citibike-tripdata.csv')
NY202004df = pd.read_csv (r'..\data\202004-citibike-tripdata.csv')
NY202005df = pd.read_csv (r'..\data\202005-citibike-tripdata.csv')
NY202006df = pd.read_csv (r'..\data\202006-citibike-tripdata.csv')
NY202007df = pd.read_csv (r'..\data\202007-citibike-tripdata.csv')
NY202008df = pd.read_csv (r'..\data\202008-citibike-tripdata.csv')
NY202009df = pd.read_csv (r'..\data\202009-citibike-tripdata.csv')
NY202010df = pd.read_csv (r'..\data\202010-citibike-tripdata.csv')
NY202011df = pd.read_csv (r'..\data\202011-citibike-tripdata.csv')
NY202012df = pd.read_csv (r'..\data\202012-citibike-tripdata.csv')

# %%
NY01df =  NY202001df.sample(frac=0.001).reset_index(drop=True)
NY02df =  NY202002df.sample(frac=0.001).reset_index(drop=True)
NY03df =  NY202003df.sample(frac=0.001).reset_index(drop=True)
NY04df =  NY202004df.sample(frac=0.001).reset_index(drop=True)
NY05df =  NY202005df.sample(frac=0.001).reset_index(drop=True)
NY06df =  NY202006df.sample(frac=0.001).reset_index(drop=True)
NY07df =  NY202007df.sample(frac=0.001).reset_index(drop=True)
NY08df =  NY202008df.sample(frac=0.001).reset_index(drop=True)
NY09df =  NY202009df.sample(frac=0.001).reset_index(drop=True)
NY10df =  NY202010df.sample(frac=0.001).reset_index(drop=True)
NY11df =  NY202011df.sample(frac=0.001).reset_index(drop=True)
NY12df =  NY202012df.sample(frac=0.001).reset_index(drop=True)

# %%
NY2020df = pd.concat([NY01df,NY02df,NY03df,NY04df,NY05df,NY06df,NY07df,NY08df,NY09df,NY10df,NY11df,NY12df])
NY2020df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0              249  2020-01-11 20:20:28.3120  2020-01-11 20:24:37.7850
# 1              165  2020-01-13 18:38:17.7750  2020-01-13 18:41:03.7500
# 2             1092  2020-01-10 17:19:26.7130  2020-01-10 17:37:39.6690
# 3              266  2020-01-28 17:31:43.9010  2020-01-28 17:36:09.9320
# 4              422  2020-01-28 08:39:55.2600  2020-01-28 08:46:57.3140
# ...            ...                       ...                       ...
# 1084          3170  2020-12-21 20:07:54.2140  2020-12-21 21:00:44.3330
# 1085          2817  2020-12-10 13:08:04.6020  2020-12-10 13:55:02.1880
# 1086          1021  2020-12-23 16:56:57.7440  2020-12-23 17:13:59.2120
# 1087           442  2020-12-25 16:17:19.6370  2020-12-25 16:24:42.5650
# 1088          1143  2020-12-13 12:47:10.0880  2020-12-13 13:06:13.4240
#
#       start station id           start station name  start station latitude  \
# ...

# %%
NY2020df.to_csv(r'2020_sample_data.csv',index=False)

# %%
NY201901df = pd.read_csv (r'..\data\201901-citibike-tripdata.csv')
NY201902df = pd.read_csv (r'..\data\201902-citibike-tripdata.csv')
NY201903df = pd.read_csv (r'..\data\201903-citibike-tripdata.csv')
NY201904df = pd.read_csv (r'..\data\201904-citibike-tripdata.csv')
NY201905df = pd.read_csv (r'..\data\201905-citibike-tripdata.csv')
NY201906df = pd.read_csv (r'..\data\201906-citibike-tripdata.csv')
NY201907df = pd.read_csv (r'..\data\201907-citibike-tripdata.csv')
NY201908df = pd.read_csv (r'..\data\201908-citibike-tripdata.csv')
NY201909df = pd.read_csv (r'..\data\201909-citibike-tripdata.csv')
NY201910df = pd.read_csv (r'..\data\201910-citibike-tripdata.csv')
NY201911df = pd.read_csv (r'..\data\201911-citibike-tripdata.csv')
NY201912df = pd.read_csv (r'..\data\201912-citibike-tripdata.csv')

# %%
NY01bdf =  NY201901df.sample(frac=0.001).reset_index(drop=True)
NY02bdf =  NY201902df.sample(frac=0.001).reset_index(drop=True)
NY03bdf =  NY201903df.sample(frac=0.001).reset_index(drop=True)
NY04bdf =  NY201904df.sample(frac=0.001).reset_index(drop=True)
NY05bdf =  NY201905df.sample(frac=0.001).reset_index(drop=True)
NY06bdf =  NY201906df.sample(frac=0.001).reset_index(drop=True)
NY07bdf =  NY201907df.sample(frac=0.001).reset_index(drop=True)
NY08bdf =  NY201908df.sample(frac=0.001).reset_index(drop=True)
NY09bdf =  NY201909df.sample(frac=0.001).reset_index(drop=True)
NY10bdf =  NY201910df.sample(frac=0.001).reset_index(drop=True)
NY11bdf =  NY201911df.sample(frac=0.001).reset_index(drop=True)
NY12bdf =  NY201912df.sample(frac=0.001).reset_index(drop=True)

# %%
NY2019df = pd.concat([NY01bdf,NY02bdf,NY03bdf,NY04bdf,NY05bdf,NY06bdf,NY07bdf,NY08bdf,NY09bdf,NY10bdf,NY11bdf,NY12bdf])
NY2019df
# Out:
#      tripduration                 starttime                  stoptime  \
# 0             504  2019-01-07 07:54:27.0100  2019-01-07 08:02:51.9360
# 1             314  2019-01-14 19:11:12.1360  2019-01-14 19:16:26.8900
# 2             409  2019-01-24 18:45:47.1630  2019-01-24 18:52:36.5570
# 3             815  2019-01-23 12:35:05.7880  2019-01-23 12:48:41.4180
# 4             351  2019-01-10 18:15:09.1290  2019-01-10 18:21:00.4590
# ..            ...                       ...                       ...
# 950           472  2019-12-16 19:00:41.7340  2019-12-16 19:08:34.0670
# 951           412  2019-12-22 19:08:51.7820  2019-12-22 19:15:43.8900
# 952           660  2019-12-16 15:37:14.5360  2019-12-16 15:48:14.8990
# 953           355  2019-12-13 01:41:07.1680  2019-12-13 01:47:02.9960
# 954           134  2019-12-16 12:38:45.7340  2019-12-16 12:41:00.6530
#
#      start station id      start station name  start station latitude  \
# ...

# %%
NY2019df.to_csv(r'2019_sample_data.csv',index=False)

# %%
NY201801df = pd.read_csv (r'..\data\201801-citibike-tripdata.csv')
NY201802df = pd.read_csv (r'..\data\201802-citibike-tripdata.csv')
NY201803df = pd.read_csv (r'..\data\201803-citibike-tripdata.csv')
NY201804df = pd.read_csv (r'..\data\201804-citibike-tripdata.csv')
NY201805df = pd.read_csv (r'..\data\201805-citibike-tripdata.csv')
NY201806df = pd.read_csv (r'..\data\201806-citibike-tripdata.csv')
NY201807df = pd.read_csv (r'..\data\201807-citibike-tripdata.csv')
NY201808df = pd.read_csv (r'..\data\201808-citibike-tripdata.csv')
NY201809df = pd.read_csv (r'..\data\201809-citibike-tripdata.csv')
NY201810df = pd.read_csv (r'..\data\201810-citibike-tripdata.csv')
NY201811df = pd.read_csv (r'..\data\201811-citibike-tripdata.csv')
NY201812df = pd.read_csv (r'..\data\201812-citibike-tripdata.csv')

# %%
NY01cdf =  NY201801df.sample(frac=0.001).reset_index(drop=True)
NY02cdf =  NY201802df.sample(frac=0.001).reset_index(drop=True)
NY03cdf =  NY201803df.sample(frac=0.001).reset_index(drop=True)
NY04cdf =  NY201804df.sample(frac=0.001).reset_index(drop=True)
NY05cdf =  NY201805df.sample(frac=0.001).reset_index(drop=True)
NY06cdf =  NY201806df.sample(frac=0.001).reset_index(drop=True)
NY07cdf =  NY201807df.sample(frac=0.001).reset_index(drop=True)
NY08cdf =  NY201808df.sample(frac=0.001).reset_index(drop=True)
NY09cdf =  NY201809df.sample(frac=0.001).reset_index(drop=True)
NY10cdf =  NY201810df.sample(frac=0.001).reset_index(drop=True)
NY11cdf =  NY201811df.sample(frac=0.001).reset_index(drop=True)
NY12cdf =  NY201812df.sample(frac=0.001).reset_index(drop=True)

# %%
NY2018df = pd.concat([NY01cdf,NY02cdf,NY03cdf,NY04cdf,NY05cdf,NY06cdf,NY07cdf,NY08cdf,NY09cdf,NY10cdf,NY11cdf,NY12cdf])
NY2018df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0              150  2018-01-10 06:25:17.5190  2018-01-10 06:27:48.2120
# 1              491  2018-01-24 08:55:52.2290  2018-01-24 09:04:03.6110
# 2              238  2018-01-26 08:50:40.8910  2018-01-26 08:54:39.0290
# 3              921  2018-01-22 13:36:19.1660  2018-01-22 13:51:40.7690
# 4              247  2018-01-15 17:32:04.0540  2018-01-15 17:36:11.2030
# ...            ...                       ...                       ...
# 1012           374  2018-12-07 14:21:29.2760  2018-12-07 14:27:43.2840
# 1013           718  2018-12-14 15:51:06.9900  2018-12-14 16:03:05.1310
# 1014           602  2018-12-05 17:53:08.1930  2018-12-05 18:03:11.0700
# 1015           550  2018-12-22 13:46:17.8330  2018-12-22 13:55:28.6560
# 1016           519  2018-12-08 08:06:56.0200  2018-12-08 08:15:35.8270
#
#       start station id          start station name  start station latitude  \
# ...

# %%
NY2018df.to_csv(r'2018_sample_data.csv',index=False)
